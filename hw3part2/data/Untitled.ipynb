# %%
import pandas

# %%
pandas.read_csv("fifa-matches.csv")
# Out:
#              Team      Opponent  Goals Made  Goals Conceded  Delta Goals  \
# 0          Brazil       Germany           1               7           -6
# 1         Germany     Argentina           1               0            1
# 2       Argentina   Netherlands           0               0            0
# 3     Netherlands        Brazil           3               0            3
# 4          Brazil      Colombia           2               1            1
# 5          France       Germany           0               1           -1
# 6     Netherlands        Mexico           2               1            1
# 7       CostaRica        Greece           1               1            0
# 8       Argentina   Switzerland           1               0            1
# 9         Belgium  UnitedStates           2               1            1
# 10    Netherlands     CostaRica           0               0            0
# 11      Argentina       Belgium           1               0            1
# ...

# %%
pandas.read_csv("fifa-tree.csv")
# Out:
#             Team      Opponent  Wins  Losses  ParentGame
# 0         Brazil         Chile     1       0         4.0
# 1       Colombia       Uruguay     1       0        15.0
# 2         France       Nigeria     1       0         5.0
# 3        Germany       Algeria     1       0        16.0
# 4         Brazil      Colombia     1       0         6.0
# 5         France       Germany     0       1        17.0
# 6         Brazil       Germany     0       1         7.0
# 7        Germany     Argentina     1       0        26.0
# 8    Netherlands        Mexico     1       0        12.0
# 9      CostaRica        Greece     1       0        22.0
# 10     Argentina   Switzerland     1       0        13.0
# 11       Belgium  UnitedStates     1       0        23.0
# 12   Netherlands     CostaRica     1       0        14.0
# 13     Argentina       Belgium     1       0        24.0
# 14   Netherlands     Argentina     0       1        25.0
# ...
